# %% [markdown]
# #### 과목별 점수를 세로 막대그래프로 표현하시오
# #### 그래프 제목: "과목별 점수"
# #### x축: 과목 / y축: 점수
# #### 막대 위에 점수 값 표시
# #### python항목에만 점수표시

# %%
#반드시 pandas는 import하여 사용한다.
import pandas as pd
# matplotlib 매트플롯립도 반드시 import하여 사용한다.
import matplotlib.pyplot as plt

#데이터 생성하기
df = pd.DataFrame({
    "과목": ["Java", "Python", "React", "SQL"],
    "점수": [85, 90, 75, 80]
})

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(6,4))

bars= plt.bar(df["과목"], df["점수"],width=0.4, color='skyblue')

for i in range(len(bars)):
    bar = bars[i]
    he = bar.get_height() # 세로막대 높이 값
    
    # python인 경우만 출력
    if df['과목'][i] == 'Python':
        plt.text(bar.get_x()+bar.get_width()/2,he,str(he), ha='center',va='bottom')
   

# 차트제목, 가로축 제목, 세로축 제목 저장
plt.title("과목별 점수")
plt.xlabel("과목")
plt.ylabel("점수")

# 반드시 저장이 먼저이다.
plt.savefig('example_graph01.png',dpi=300)

# 그래프 출력
plt.show()

# %% [markdown]
# ### 공부시간을 가로 막대그래프로 표현하시오
# ### 막대 두께를 0.5로 설정
# ### 그래프 제목: "학생별 공부시간"
# ### 아래 데이터를 이용해 작성하시오
# ### '김학생'만 빼고 출력하시오

# %%
#반드시 pandas는 import하여 사용한다.
import pandas as pd
# matplotlib 매트플롯립도 반드시 import하여 사용한다.
import matplotlib.pyplot as plt

#데이터 생성하기
df = pd.DataFrame({
    "이름": ["김학생", "이학생", "박학생", "최학생"],
    "공부시간": [3, 5, 2, 4]
})

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(7,3))

df = df[df['이름'] != '김학생'] #김학생만 빼고 출력
plt.barh(df["이름"], df["공부시간"],height=0.4, color='skyblue')      


# 차트제목, 가로축 제목, 세로축 제목 저장
plt.title("학생별 공부시간")
plt.xlabel("공부시간")
plt.ylabel("이름")

plt.show()

# %% [markdown]
# ### 매출 데이터를 선그래프로 표현
# ### marker 추가
# ### 선 아래 영역을 색으로 채우기
# ### 그래프 제목: "월별 매출 변화"

# %%
#반드시 pandas는 import하여 사용한다.
import pandas as pd
# matplotlib 매트플롯립도 반드시 import하여 사용한다.
import matplotlib.pyplot as plt
# 숫자 계산을 쉽게 하기 위한 라이브러리 불러오기
import numpy as np
# 데이터 사이를 부드럽게 연결해주는 함수 가져오기
from scipy.interpolate import make_interp_spline

#데이터 생성하기
df = pd.DataFrame({
    "월": ["1월", "2월", "3월", "4월"],
    "매출": [100, 150, 130, 170]
})

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(5,3))

#꺾은선 그래프 출력
plt.plot(df["월"], df["매출"],marker='s', color='skyblue')

#꺾은선 영역 그래프
plt.fill_between(df['월'],df['매출'],alpha=0.1)

# 차트제목, 가로축 제목, 세로축 제목 저장
plt.title("월별 매출 변화")
plt.xlabel("월")
plt.ylabel("매출")


plt.show()

# %% [markdown]
# #### 금액을 기준으로 원형 그래프 생성
# #### 퍼센트 표시
# #### 시작 각도 90도 설정
# #### 그래프 제목: "지출 비율"

# %%
#반드시 pandas는 import하여 사용한다.
import pandas as pd
# matplotlib 매트플롯립도 반드시 import하여 사용한다.
import matplotlib.pyplot as plt

#데이터 생성하기
df = pd.DataFrame({
    "카테고리": ["식비", "교통", "쇼핑", "기타"],
    "금액": [300000, 100000, 200000, 150000]
})

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(6,6))
# 원형 그래프 만들기 : plt.pie(항목)
# labels = merged['지역'] =>원형 그래프 각각 파이의 이름
# autopct = '%1.1f%%' => 원형 그래프 각 조각의 백분율 출력
# startangle = 90 => 원형 그래프 시작 위치, 90이면 위쪽부터 시작
plt.pie(df['금액'], labels=df['카테고리'], autopct='%1.1f%%', startangle=90)

# 원형 그래프는 x,y축이 필요하지 않다.
plt.title('지출 비율')
plt.show()

# %% [markdown]
# # 사용자 비율을 도넛 그래프로 표현
# # 가운데 원 추가
# # 그래프 제목: "OS 점유율"

# %%
#반드시 pandas는 import하여 사용한다.
import pandas as pd
# matplotlib 매트플롯립도 반드시 import하여 사용한다.
import matplotlib.pyplot as plt

#데이터 생성하기
df = pd.DataFrame({
    "OS": ["Windows", "Mac", "Linux"],
    "사용자수": [70, 20, 10]
})

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(5,5))
# 원형 그래프 만들기 : plt.pie(항목)
plt.pie(df['사용자수'], labels=df['OS'], autopct='%1.1f%%', startangle=90)

# 도넛 그래프 만들기
# plt.Circle((0,0),0.6,fc='white')
# (0,0) => 중심, 반지름 0.6 짜리, 흰색원을 그린다.
# plt.gca().add_artist(center_circle) => 그래프에 추가해줘
centre_circle = plt.Circle((0,0),0.4,fc='white')
plt.gca().add_artist(centre_circle)

# 원형 그래프는 x,y축이 필요하지 않다.
plt.title('OS 점유율')
plt.show()

# %% [markdown]
# ### 두 데이터를 부서 기준으로 병합하시오 (outer 조인)
# ### 결측치는 각 컬럼의 평균값으로 처리하시오
# ### 기본급과 성과급을 이용하여 누적 세로 막대그래프를 생성하시오
# ### 그래프 구성:
# ### 아래: 기본급
# ### 위: 성과급 (누적)
# ### 범례(legend) 추가
# ### 그래프 제목: "부서별 급여 구조"
# ### x축: 부서 / y축: 금액
# ### 그래프를 이미지로 저장 (salary_chart.png, dpi=300)

# %%
#반드시 pandas는 import하여 사용한다.
import pandas as pd
# matplotlib 매트플롯립도 반드시 import하여 사용한다.
import matplotlib.pyplot as plt

#데이터 생성하기
df1 = pd.DataFrame({
    "부서": ["개발팀", "영업팀", "인사팀"],
    "기본급": [300, 250, 200]
})
df2 = pd.DataFrame({
    "부서": ["개발팀", "영업팀", "마케팅팀"],
    "성과급": [100, 80, 70]
})

#데이터 전처리를 위해 merge(명함)을 진행한다.
#outer로 병합하면 df1과 df2가 합집합이 된다.
merged = pd.merge(df1,df2,on="부서",how="outer")

merged['기본급'] = merged['기본급'].fillna(merged['기본급'].mean())
merged['성과급'] = merged['성과급'].fillna(merged['성과급'].mean())

#-------------------------------------
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

#첫번째 막대
plt.bar(merged['부서'],merged['기본급'],label='기본급')
#두번째 막대
plt.bar(merged['부서'],merged['성과급'],bottom=merged['기본급'],label='성과급')

plt.title('부서별 급여 구조')
plt.xlabel('부서')
plt.ylabel('금액')

#범례표시
plt.legend()

plt.show()

# %% [markdown]
# ### 두 데이터를 부서 기준으로 병합하시오 (outer 조인)
# ### 결측치는 각 컬럼의 평균값으로 처리하시오
# ### 기본급과 성과급, 수당을 이용하여 누적 세로 막대그래프를 생성하시오
# ### 그래프 구성:
# ### 아래: 기본급
# ### 위: 성과급 (누적)
# ### 위: 수당 (누적)
# ### 범례(legend) 추가
# ### 그래프 제목: "부서별 급여 구조"
# ### x축: 부서 / y축: 금액
# ### 그래프를 이미지로 저장 (salary_chart.png, dpi=300)

# %%
#반드시 pandas는 import하여 사용한다.
import pandas as pd
# matplotlib 매트플롯립도 반드시 import하여 사용한다.
import matplotlib.pyplot as plt

#데이터 생성하기
df1 = pd.DataFrame({
    "부서": ["개발팀", "영업팀", "인사팀"],
    "기본급": [300, 250, 200]
})
df2 = pd.DataFrame({
    "부서": ["개발팀", "영업팀", "마케팅팀"],
    "성과급": [100, 80, 70]
})
df3 = pd.DataFrame({
    "부서": ["개발팀", "영업팀", "인사팀"],
    "수당": [50, 40, 30]
})

plt.figure(figsize=(5,5))

#데이터 전처리를 위해 merge(명함)을 진행한다.
#outer로 병합하면 df1과 df2가 합집합이 된다.
merged01 = pd.merge(df1,df2,on="부서",how="outer")
merged = pd.merge(merged01,df3,on="부서",how="outer")

merged['기본급'] = merged['기본급'].fillna(merged['기본급'].mean())
merged['성과급'] = merged['성과급'].fillna(merged['성과급'].mean())
merged['수당'] = merged['수당'].fillna(merged['수당'].mean())

#-------------------------------------
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

#첫번째 막대
plt.bar(merged['부서'],merged['기본급'],label='기본급')
#두번째 막대
plt.bar(merged['부서'],merged['성과급'],bottom=merged['기본급'],label='성과급')
#세번째 막대
plt.bar(merged['부서'],merged['수당'],bottom=merged['기본급']+merged['성과급'],label='수당')

plt.title('부서별 급여 구조(누적)')
plt.xlabel('부서')
plt.ylabel('금액')

#범례표시
plt.legend()

# 반드시 저장이 먼저이다.
plt.savefig('salary_chart.png',dpi=300)

plt.show()
