# %%
import pandas as pd

#출력옵션 설정
pd.set_option('display.max_columns',None) #모든컬럼 출력
pd.set_option('display.width',1000) #출력너비 지정
pd.set_option('display.unicode.east_asian_width',True) #한글정렬 맞추기

#호텔 데이터
hotel = pd.read_csv('greenData/resort/hotel.csv', encoding='utf-8')
hotelDf = pd.DataFrame(hotel)

#객실 데이터
room = pd.read_csv('greenData/resort/room.csv', encoding='cp949')
roomDf = pd.DataFrame(room)

# #회원 데이터
member = pd.read_csv('greenData/resort/member.csv', encoding='utf-8')
memberDf = pd.DataFrame(member)

# #비회원 데이터
guest = pd.read_csv('greenData/resort/guest.csv', encoding='utf-8')
guestDf = pd.DataFrame(guest)

# #문의게시판 데이터
board = pd.read_csv('greenData/resort/board.csv', encoding='cp949')
boardDf = pd.DataFrame(board)



boardDf
# Out:
#     b_code  m_code                            b_title b_writer  b_pw  readcount            b_date                                b_content  ref  re_step  re_level          b_update  b_upload
# 0        1      11  서울 특급호텔 조식 포함 여부 문의   김태희   123          1  2025-10-05 10:12   조식 포함 예약 가능 여부 문의드립니다.    1        1         1  2025-10-05 10:12       NaN
# 1        2     301                      답변드립니다.   관리자   123          1  2025-10-05 10:28               조식 포함 예약 가능합니다.    1        2         2  2025-10-05 10:28       NaN
# 2        3      25  부산 해운대 호텔 오션뷰 가격 문의   이민호   123          1  2025-10-18 11:03           오션뷰 객실 요금 문의드립니다.    2        1         1  2025-10-18 11:03       NaN
# 3        4     301                      답변드립니다.   관리자   123          1  2025-10-18 11:20           요금은 날짜에 따라 상이합니다.    2        2         2  2025-10-18 11:20       NaN
# 4        5      44   제주 리조트 수영장 운영시간 문의   박보검   123          1   2025-11-02 9:45      수영장 이용 가능 시간 문의드립니다.    3        1         1   2025-11-02 9:45       NaN
# ..     ...     ...                                ...      ...   ...        ...               ...                                      ...  ...      ...       ...               ...       ...
# 64      65     301                      답변드립니다.   관리자   123          1  2026-03-18 14:31             객실 상황에 따라 가능합니다.   35        2         2  2026-03-18 14:31       NaN
# 65      66     272    런던 호텔 공항 셔틀 서비스 문의   한소희   123          1  2026-03-19 14:44        공항 셔틀 제공 여부 문의드립니다.   36        1         1  2026-03-19 14:44       NaN
# 66      67     301                      답변드립니다.   관리자   123          1  2026-03-19 15:05                         셔틀 제공됩니다.   36        2         2  2026-03-19 15:05       NaN
# 67      68     295     인천 호텔 레이트 체크아웃 문의   이정재   123          1  2026-03-19 16:02  레이트 체크아웃 가능 여부 문의드립니다.   37        1         1  2026-03-19 16:02       NaN
# 68      69     300    홍콩 호텔 수영장 무료 이용 문의   장동건   123          1   2026-03-20 9:33             수영장 무료 이용 가능한가요?   38        1         1   2026-03-20 9:33       NaN
#
# [69 rows x 13 columns]
